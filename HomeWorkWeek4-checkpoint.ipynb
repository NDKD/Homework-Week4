# %% [markdown]
#  #  A Whale off the Port(folio)
#  ---
#
#  In this assignment, you'll get to use what you've learned this week to evaluate the performance among various algorithmic, hedge, and mutual fund portfolios and compare them against the S&P TSX 60 Index.

# %%
# Initial imports
import pandas as pd
import numpy as np
import datetime as dt
from pathlib import Path
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# # Data Cleaning
#
# In this section, you will need to read the CSV files into DataFrames and perform any necessary data cleaning steps. After cleaning, combine all DataFrames into a single DataFrame.
#
# Files:
#
# * `whale_returns.csv`: Contains returns of some famous "whale" investors' portfolios.
#
# * `algo_returns.csv`: Contains returns from the in-house trading algorithms from Harold's company.
#
# * `sp_tsx_history.csv`: Contains historical closing prices of the S&P TSX 60 Index.

# %% [markdown]
# ## Whale Returns
#
# Read the Whale Portfolio daily returns and clean the data.

# %%
csv_path = Path("whale_returns.csv")

#whale_data = pd.read_csv(csv_path,index_col='Date',parse_dates=True)

# %%
whale_data = pd.read_csv(csv_path,index_col='Date', infer_datetime_format=True, parse_dates=True )

# %%
# Reading whale returns
#print(whale_data)
whale_data.sort_index()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-01-04                   0.000919            0.000157
# 2015-01-05                   0.006051            0.002551
# 2015-01-06                   0.002081           -0.000113
# 2015-01-07                  -0.001365            0.002100
# 2015-01-09                  -0.018980           -0.012439
# ...                               ...                 ...
# 2019-11-03                   0.015435            0.005009
# 2019-11-04                   0.003406           -0.003959
# 2019-12-02                   0.000000            0.000000
# 2019-12-03                  -0.000180            0.003514
# 2019-12-04                   0.005663           -0.001165
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2015-01-04                    -0.002002               -0.003865
# 2015-01-05                     0.006526                0.009650
# ...

# %%
# Count nulls


whale_data.isnull().sum().sum()
# Out:
# 4

# %%
# Drop nulls
whale_df1 = whale_data.dropna() 

whale_df1.sort_index()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-01-04                   0.000919            0.000157
# 2015-01-05                   0.006051            0.002551
# 2015-01-06                   0.002081           -0.000113
# 2015-01-07                  -0.001365            0.002100
# 2015-01-09                  -0.018980           -0.012439
# ...                               ...                 ...
# 2019-11-03                   0.015435            0.005009
# 2019-11-04                   0.003406           -0.003959
# 2019-12-02                   0.000000            0.000000
# 2019-12-03                  -0.000180            0.003514
# 2019-12-04                   0.005663           -0.001165
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2015-01-04                    -0.002002               -0.003865
# 2015-01-05                     0.006526                0.009650
# ...

# %% [markdown]
# ## Algorithmic Daily Returns
#
# Read the algorithmic daily returns and clean the data.

# %%
# Reading algorithmic returns
csv_path = Path("algo_returns.csv")
algo_data = pd.read_csv(csv_path, index_col='Date', infer_datetime_format=True, parse_dates=True )
algo_data.sort_index()
# Out:
#               Algo 1    Algo 2
# Date
# 2014-05-28  0.001745       NaN
# 2014-05-29  0.003978       NaN
# 2014-05-30  0.004464       NaN
# 2014-06-02  0.005692       NaN
# 2014-06-03  0.005292       NaN
# ...              ...       ...
# 2019-04-25  0.000682 -0.007247
# 2019-04-26  0.002981  0.005256
# 2019-04-29  0.005208  0.002829
# 2019-04-30 -0.002944 -0.001570
# 2019-05-01  0.000094 -0.007358
#
# [1241 rows x 2 columns]

# %%
# Count nulls
algo_data.isnull().sum().sum()
# Out:
# 6

# %%
# Drop nulls
algo_df1 = algo_data.dropna() 
algo_df1.sort_index()
# Out:
#               Algo 1    Algo 2
# Date
# 2014-06-05  0.004062  0.013285
# 2014-06-06  0.001857  0.008284
# 2014-06-09 -0.005012  0.005668
# 2014-06-10  0.004406 -0.000735
# 2014-06-11  0.004760 -0.003761
# ...              ...       ...
# 2019-04-25  0.000682 -0.007247
# 2019-04-26  0.002981  0.005256
# 2019-04-29  0.005208  0.002829
# 2019-04-30 -0.002944 -0.001570
# 2019-05-01  0.000094 -0.007358
#
# [1235 rows x 2 columns]

# %% [markdown]
# ## S&P TSX 60 Returns
#
# Read the S&P TSX 60 historic closing prices and create a new daily returns DataFrame from the data.

# %%
# Reading S&P TSX 60 Closing Prices
# Reading algorithmic returns
csv_path = Path("sp_tsx_history.csv")
tsx_data = pd.read_csv(csv_path,index_col='Date', infer_datetime_format=True, parse_dates=True)
tsx_data.sort_index()
# Out:
#                  Close
# Date
# 2012-10-01  $12,370.19
# 2012-10-02  $12,391.23
# 2012-10-03  $12,359.47
# 2012-10-04  $12,447.68
# 2012-10-05  $12,418.99
# ...                ...
# 2019-12-20  $17,118.44
# 2019-12-23  $17,128.71
# 2019-12-24  $17,180.15
# 2019-12-27  $17,168.21
# 2019-12-30  $17,098.56
#
# [1818 rows x 1 columns]

# %%
# Check Data Types
tsx_data.dtypes
# Out:
# Close    object
# dtype: object

# %%
# Fix Data Types
#tsx_data['Date'] = tsx_data['Date'].astype('datetime64[ns]')

#def convert_currency(val):
    #"""
   # Convert the string number value to a float
     #- Remove $
     #- Remove commas
     #- Convert to float type
   # """
    #new_val = val.replace('$','').replace(',', '').replace(".",".")
    #return float(new_val)

tsx_data["Close"] = tsx_data["Close"].str.replace("$", "")
tsx_data["Close"] = tsx_data["Close"].str.replace(",", "")
tsx_data["Close"].head(10)    
#tsx_data['Close'].apply(convert_currency)

#tsx_data[['Close']] = tsx_data[['Close']].apply(pd.to_numeric)
tsx_data["Close"] = pd.to_numeric(tsx_data["Close"], downcast="float")



tsx_data.dtypes
# Out:
# <ipython-input-12-a0df4cc6c794>:14: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   tsx_data["Close"] = tsx_data["Close"].str.replace("$", "")
# Close    float32
# dtype: object

# %%
# Calculate Daily Returns
#index_col=("Date")
#tsx_data = tsx_data.reset_index()
#tsx_data = tsx_data.pivot_table(values="Close", index="Date")

#tsx_data.head()
#tsx_data = tsx_data(values="Close", index="Date")
#tsx_data = tsx_data(index= "Date")
daily_returns = tsx_data.pct_change()
daily_returns.head()
# Out:
#                Close
# Date
# 2012-10-01       NaN
# 2012-10-02  0.001701
# 2012-10-03 -0.002563
# 2012-10-04  0.007137
# 2012-10-05 -0.002305

# %%
# Drop nulls
tsx_df1 = daily_returns.dropna() 
print(tsx_df1)
tsx_df1.sample()
# Out:
#                Close
# Date
# 2012-10-02  0.001701
# 2012-10-03 -0.002563
# 2012-10-04  0.007137
# 2012-10-05 -0.002305
# 2012-10-09 -0.011709
# ...              ...
# 2019-12-20  0.003188
# 2019-12-23  0.000600
# 2019-12-24  0.003003
# 2019-12-27 -0.000695
# 2019-12-30 -0.004057
#
# [1817 rows x 1 columns]
#                Close
# Date
# 2014-12-08 -0.022768

# %%
# Rename `Close` Column to be specific to this portfolio.
tsx_df1.rename(columns = {'Date' : 'Date','Close': 'S&P TSX'}, inplace = True)
tsx_df1.sort_index()

tsx_df1.head()
# Out:
# C:\Users\nd321\anaconda3\lib\site-packages\pandas\core\frame.py:4441: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
#              S&P TSX
# Date
# 2012-10-02  0.001701
# 2012-10-03 -0.002563
# 2012-10-04  0.007137
# 2012-10-05 -0.002305
# 2012-10-09 -0.011709

# %% [markdown]
# ## Combine Whale, Algorithmic, and S&P TSX 60 Returns

# %%
# Join Whale Returns, Algorithmic Returns, and the S&P TSX 60 Returns into a single DataFrame with columns for each portfolio's returns.

#whale_df1 = whale_df1.reset_index()
#whale_df1 = whale_df1.pivot_table(index="Date")

#algo_df1 = algo_df1.reset_index()
#algo_df1 = algo_df1.pivot_table(index="Date")


#tsx_df1 = tsx_df1.reset_index()
#tsx_df1 = tsx_df1.pivot_table(index="Date")

joined_df1 = pd.concat([ whale_df1 , algo_df1 , tsx_df1],axis = "columns" , join ='inner' )
#Sort datetime index in ascending order
joined_df1 = joined_df1.sort_index()
# Set the column names to 'AMZN' and 'S&P 500'
joined_df1.columns = ["SFML" , "P&CO" , "TGML" , "BERK HAWY" , "ALGO1" , "ALGO2" , "S&P TSX"]


joined_df1.head()
# Out:
#                 SFML      P&CO      TGML  BERK HAWY     ALGO1     ALGO2  \
# Date
# 2015-01-05  0.006051  0.002551  0.006526   0.009650  0.013712 -0.015621
# 2015-01-06  0.002081 -0.000113  0.000837   0.002916  0.002307 -0.011984
# 2015-01-07 -0.001365  0.002100  0.005815  -0.001304  0.003473  0.009418
# 2015-01-09 -0.018980 -0.012439 -0.022997  -0.037577 -0.009436 -0.001881
# 2015-01-12  0.004271  0.010081  0.009055   0.010649 -0.019423 -0.002282
#
#              S&P TSX
# Date
# 2015-01-05 -0.024465
# 2015-01-06 -0.010139
# 2015-01-07  0.002683
# 2015-01-09 -0.005035
# 2015-01-12 -0.008336

# %% [markdown]
# ---

# %% [markdown]
# # Conduct Quantitative Analysis
#
# In this section, you will calculate and visualize performance and risk metrics for the portfolios.

# %% [markdown]
# ## Performance Anlysis
#
# #### Calculate and Plot the daily returns.

# %%
# Plot daily returns of all portfolios
ax=tsx_df1.plot(figsize=(30,15), fontsize=40, rot=90)
whale_df1.plot(ax=ax)
algo_df1.plot(ax=ax)
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# #### Calculate and Plot cumulative returns.

# %%
# Calculate cumulative returns of all portfolios
joined_df2 = joined_df1.dropna()
#columns = {"SOROS FUND MANAGEMENT LLC",	"PAULSON & CO.INC.", "TIGER GLOBAL MANAGEMENT LLC", "BERKSHIRE HATHAWAY INC","Algo 1","Algo 2","S&P TSX"


#joined_df2 = joined_df2.iloc[:],[(0,1,2,3,4,5,6)]
#joined_df2.head()
#joined_df2['cumulative_returns'] = (joined_df2 + 1).cumprod()

#joined_df2['cumulative_returns'] = 100  * (joined_df2.cumsum() / joined_df2.sum())
#joined_df2= np.cumsum(joined_df2)
#joined_df2.head()

# %%
#joined_sum = joined_df2.groupby([])
#joined_sum.head()

# %%
# Calculate cumulative returns of all portfolios
#joined_df2['cumulative_returns'] = 100  * (joined_cumsum / joined_sum)
joined_df2  = (1 + joined_df2).cumprod()

joined_df2.head()
# Out:
#                 SFML      P&CO      TGML  BERK HAWY     ALGO1     ALGO2  \
# Date
# 2015-01-05  1.006051  1.002551  1.006526   1.009650  1.013712  0.984379
# 2015-01-06  1.008145  1.002438  1.007368   1.012594  1.016050  0.972582
# 2015-01-07  1.006769  1.004543  1.013226   1.011273  1.019579  0.981742
# 2015-01-09  0.987661  0.992048  0.989925   0.973273  1.009958  0.979895
# 2015-01-12  0.991880  1.002048  0.998889   0.983637  0.990341  0.977659
#
#              S&P TSX
# Date
# 2015-01-05  0.975535
# 2015-01-06  0.965644
# 2015-01-07  0.968235
# 2015-01-09  0.963359
# 2015-01-12  0.955329

# %%
# Plot cumulative returns

joined_df2.plot(fontsize=40, figsize = (30,15))

#joined_df2.plot(ax=ax)
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ---

# %% [markdown]
# ## Risk Analysis
#
# Determine the _risk_ of each portfolio:
#
# 1. Create a box plot for each portfolio.
# 2. Calculate the standard deviation for all portfolios.
# 4. Determine which portfolios are riskier than the S&P TSX 60.
# 5. Calculate the Annualized Standard Deviation.

# %% [markdown]
# ### Create a box plot for each portfolio

# %%
# Box plot to visually show risk
joined_df2.boxplot(rot=90, fontsize=20, figsize=(30,15))
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Calculate Standard Deviations

# %%
# Calculate the daily standard deviations of all portfolios

joined_df3= joined_df1.dropna()
joined_df3 .sort_index()
# Out:
#                 SFML      P&CO      TGML  BERK HAWY     ALGO1     ALGO2  \
# Date
# 2015-01-05  0.006051  0.002551  0.006526   0.009650  0.013712 -0.015621
# 2015-01-06  0.002081 -0.000113  0.000837   0.002916  0.002307 -0.011984
# 2015-01-07 -0.001365  0.002100  0.005815  -0.001304  0.003473  0.009418
# 2015-01-09 -0.018980 -0.012439 -0.022997  -0.037577 -0.009436 -0.001881
# 2015-01-12  0.004271  0.010081  0.009055   0.010649 -0.019423 -0.002282
# ...              ...       ...       ...        ...       ...       ...
# 2019-04-24  0.002284  0.001009 -0.004000  -0.006386  0.001095  0.000399
# 2019-04-25 -0.000285 -0.001291 -0.005153   0.004848  0.000682 -0.007247
# 2019-04-26  0.008149  0.009162  0.012355   0.010434  0.002981  0.005256
# 2019-04-29  0.001254  0.002719  0.006251   0.005223  0.005208  0.002829
# 2019-04-30 -0.001295 -0.002211 -0.000259  -0.003702 -0.002944 -0.001570
#
#              S&P TSX
# Date
# 2015-01-05 -0.024465
# 2015-01-06 -0.010139
# 2015-01-07  0.002683
# ...

# %%
daily_returns1 = joined_df1
daily_returns1= daily_returns1.dropna()
daily_returns1 .head()
# Out:
#                 SFML      P&CO      TGML  BERK HAWY     ALGO1     ALGO2  \
# Date
# 2015-01-05  0.006051  0.002551  0.006526   0.009650  0.013712 -0.015621
# 2015-01-06  0.002081 -0.000113  0.000837   0.002916  0.002307 -0.011984
# 2015-01-07 -0.001365  0.002100  0.005815  -0.001304  0.003473  0.009418
# 2015-01-09 -0.018980 -0.012439 -0.022997  -0.037577 -0.009436 -0.001881
# 2015-01-12  0.004271  0.010081  0.009055   0.010649 -0.019423 -0.002282
#
#              S&P TSX
# Date
# 2015-01-05 -0.024465
# 2015-01-06 -0.010139
# 2015-01-07  0.002683
# 2015-01-09 -0.005035
# 2015-01-12 -0.008336

# %%
# daily_std1 = daily_returns1['SFML'].std()
daily_std1 = daily_returns1.std()
daily_std1
# Out:
# SFML         0.007950
# P&CO         0.006975
# TGML         0.011085
# BERK HAWY    0.013021
# ALGO1        0.007606
# ALGO2        0.008370
# S&P TSX      0.007119
# dtype: float64

# %%
daily_std1 = daily_std1.sort_values(ascending= False)
daily_std1.head(7)
# Out:
# BERK HAWY    0.013021
# TGML         0.011085
# ALGO2        0.008370
# SFML         0.007950
# ALGO1        0.007606
# S&P TSX      0.007119
# P&CO         0.006975
# dtype: float64

# %% [markdown]
# ### Determine which portfolios are riskier than the S&P TSX 60

# %%
# Determine which portfolios are riskier than the S&P TSX 60

# %%
#Cal.Variance 
#daily_returns = combined_df.pct_change()


variance =daily_returns1 ['S&P TSX'].var()
#variance =daily_returns1 .var()

variance
# Out:
# 5.0679318519541994e-05

# %%
#Cal.Co Variance
covariance = daily_returns1.cov()
                                     
covariance
# Out:
#                SFML      P&CO      TGML  BERK HAWY     ALGO1     ALGO2  \
# SFML       0.000063  0.000039  0.000049   0.000078  0.000016  0.000039
# P&CO       0.000039  0.000049  0.000034   0.000051  0.000011  0.000027
# TGML       0.000049  0.000034  0.000123   0.000059  0.000010  0.000034
# BERK HAWY  0.000078  0.000051  0.000059   0.000170  0.000022  0.000050
# ALGO1      0.000016  0.000011  0.000010   0.000022  0.000058  0.000018
# ALGO2      0.000039  0.000027  0.000034   0.000050  0.000018  0.000070
# S&P TSX    0.000030  0.000019  0.000028   0.000039  0.000016  0.000044
#
#             S&P TSX
# SFML       0.000030
# P&CO       0.000019
# TGML       0.000028
# BERK HAWY  0.000039
# ALGO1      0.000016
# ALGO2      0.000044
# S&P TSX    0.000051

# %%
# Determine which portfolios are riskier than the S&P TSX 60
#Cal Beta  of Soros Fund Management LLC vs. S&P TSX

sfml_beta = covariance.loc['SFML', 'S&P TSX'] / variance

print(f"Soros_Fund_Mgt_LLC Beta is: {sfml_beta} is greater than 0 but less than 1 , hence it indicates that it is less volatile and less risky in comparison to S&P TSX.  ")
# Out:
# Soros_Fund_Mgt_LLC Beta is: 0.5835770541551485 is greater than 0 but less than 1 , hence it indicates that it is less volatile and less risky in comparison to S&P TSX.

# %%
#Cal Beta of Paulson & co Inc vs. S&P TSX

plsn_beta = covariance.loc['P&CO', 'S&P TSX'] / variance

print(f"Paulson & Co .Inc Beta is: {plsn_beta} is greater than 0 but less than 1 , hence it indicates that it is less volatile and less risky in comparison to S&P TSX")
# Out:
# Paulson & Co .Inc Beta is: 0.38419425088460646 is greater than 0 but less than 1 , hence it indicates that it is less volatile and less risky in comparison to S&P TSX

# %%
#Cal Beta of Tiger Global Management LLC vs. S&P TSX

tgml_beta = covariance.loc['TGML', 'S&P TSX'] / variance
print(f"Tiger Global Mgt LLC Beta is: {tgml_beta} is greater than 0 but less than 1 , hence it indicates that it is less volatile and less risky in comparison to S&P TSX")
# Out:
# Tiger Global Mgt LLC Beta is: 0.5495344996145883 is greater than 0 but less than 1 , hence it indicates that it is less volatile and less risky in comparison to S&P TSX

# %%
#Cal Beta of Berkshire Hathaway LLC vs. S&P TSX

berk_beta = covariance.loc['BERK HAWY', 'S&P TSX'] / variance
print(f"Berkshire Hathaway LLC Beta is: {berk_beta} is greater than 0 but less than 1 , hence it indicates that it is less volatile and less risky in comparison to S&P TSX")
# Out:
# Berkshire Hathaway LLC Beta is: 0.7761339790517072 is greater than 0 but less than 1 , hence it indicates that it is less volatile and less risky in comparison to S&P TSX

# %%
#Cal Beta of ALGO1 vs. S&P TSX

algo1_beta = covariance.loc['ALGO1', 'S&P TSX'] / variance
print(f"ALGO 1 Beta is: {algo1_beta} is greater than 0 but less than 1 , hence it indicates that it is less volatile and less risky in comparison to S&P TSX")
# Out:
# ALGO 1 Beta is: 0.31491119195199996 is greater than 0 but less than 1 , hence it indicates that it is less volatile and less risky in comparison to S&P TSX

# %%
#Cal Beta of ALGO2 vs. S&P TSX

algo2_beta = covariance.loc['ALGO2', 'S&P TSX'] / variance
print(f"ALGO 2 Beta is: {algo2_beta} is greater than 0 but less than 1 , hence it indicates that it is less volatile and less risky in comparison to S&P TSX")
# Out:
# ALGO 2 Beta is: 0.8711419947481275 is greater than 0 but less than 1 , hence it indicates that it is less volatile and less risky in comparison to S&P TSX

# %%
#Cal Beta of S&P TSX vs. S&P TSX

SP_beta = covariance.loc['S&P TSX', 'S&P TSX'] / variance
print(f"S&P TSX 60 Beta is: {SP_beta} is the basis for this comparison analysis. It clearly indicates that the chosen scrips are less riskier than S&P TSX 60  ")
# Out:
# S&P TSX 60 Beta is: 0.9999998036479327 is the basis for this comparison analysis. It clearly indicates that the chosen scrips are less riskier than S&P TSX 60

# %% [markdown]
# ### Calculate the Annualized Standard Deviation

# %%
# Calculate the annualized standard deviation (252 trading days)
annualized_std = daily_std1 * np.sqrt(252)
annualized_std.head(8)
# Out:
# BERK HAWY    0.206704
# TGML         0.175974
# ALGO2        0.132877
# SFML         0.126197
# ALGO1        0.120744
# S&P TSX      0.113010
# P&CO         0.110728
# dtype: float64

# %%
#portfolia_a_std = np.random.normal(scale=0.5,size= 10000)
#portfolia_a_std = np.random.normal(scale=1,size= 10000)
#portfolia_a_std = np.random.normal(scale=1.5,size= 10000)
#portfolio_std =pd.dataframe(["0.5": portfolio_a_std,"1.0" :portfolio_b_std,"1.5" : portfolio_c_std ])

#annualized_std.plot.hist(stacked=True, bins=100)

# %% [markdown]
# ---

# %% [markdown]
# ## Rolling Statistics
#
# Risk changes over time. Analyze the rolling statistics for Risk and Beta.
#
# 1. Calculate and plot the rolling standard deviation for all portfolios using a 21-day window.
# 2. Calculate the correlation between each stock to determine which portfolios may mimick the S&P TSX 60.
# 3. Choose one portfolio, then calculate and plot the 60-day rolling beta for it and the S&P TSX 60.

# %% [markdown]
# ### Calculate and plot rolling `std` for all portfolios with 21-day window

# %%
# Calculate the rolling standard deviation for all portfolios using a 21-day window
joined_df1.rolling(window=21).std()
# Out:
#                 SFML      P&CO      TGML  BERK HAWY     ALGO1     ALGO2  \
# Date
# 2015-01-05       NaN       NaN       NaN        NaN       NaN       NaN
# 2015-01-06       NaN       NaN       NaN        NaN       NaN       NaN
# 2015-01-07       NaN       NaN       NaN        NaN       NaN       NaN
# 2015-01-09       NaN       NaN       NaN        NaN       NaN       NaN
# 2015-01-12       NaN       NaN       NaN        NaN       NaN       NaN
# ...              ...       ...       ...        ...       ...       ...
# 2019-04-24  0.008919  0.008181  0.010180   0.016439  0.005518  0.006908
# 2019-04-25  0.008853  0.008188  0.010307   0.016436  0.005474  0.006490
# 2019-04-26  0.008970  0.008407  0.010511   0.016413  0.005476  0.006596
# 2019-04-29  0.008849  0.008333  0.010263   0.016374  0.005092  0.006620
# 2019-04-30  0.008347  0.008315  0.009661   0.016352  0.005167  0.006548
#
#              S&P TSX
# Date
# 2015-01-05       NaN
# 2015-01-06       NaN
# 2015-01-07       NaN
# ...

# %%
# Plot the rolling standard deviation
joined_df1.rolling(window=21).std().plot(fontsize=20, figsize=(25,20))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ### Calculate and plot the correlation

# %%
# Calculate the correlation
correlation = daily_returns1.corr()
correlation
# Out:
#                SFML      P&CO      TGML  BERK HAWY     ALGO1     ALGO2  \
# SFML       1.000000  0.707963  0.558281   0.754574  0.266481  0.592810
# P&CO       0.707963  1.000000  0.439721   0.563597  0.205575  0.465056
# TGML       0.558281  0.439721  1.000000   0.410363  0.119904  0.365073
# BERK HAWY  0.754574  0.563597  0.410363   1.000000  0.226451  0.460978
# ALGO1      0.266481  0.205575  0.119904   0.226451  1.000000  0.277425
# ALGO2      0.592810  0.465056  0.365073   0.460978  0.277425  1.000000
# S&P TSX    0.522596  0.392112  0.352908   0.424329  0.294740  0.740891
#
#             S&P TSX
# SFML       0.522596
# P&CO       0.392112
# TGML       0.352908
# BERK HAWY  0.424329
# ALGO1      0.294740
# ALGO2      0.740891
# S&P TSX    1.000000

# %%
# Display de correlation matrix

sns.heatmap(correlation, vmin=-1, vmax=1)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Calculate and Plot Beta for a chosen portfolio and the S&P 60 TSX

# %%
# Calculate covariance of a single portfolio

covariance_algo1 =daily_returns1['ALGO1'].cov(daily_returns1['S&P TSX'])
                                       
print(f"ALGO 1 covariance is: {covariance_algo1}")
# Out:
# ALGO 1 covariance is: 1.5959484602304036e-05

# %%
# Calculate variance of S&P 60 TSX
#daily_returns1 = joined_df1
#variance =joined_df1 ['S&P TSX'].var()
variance =daily_returns1 ['S&P TSX'].var()

print(f"S&P 60 TSX variance is: {variance}")
# Out:
# S&P 60 TSX variance is: 5.0679318519541994e-05

# %%
# Computing beta
beta_algo1 = covariance_algo1 / variance
print(f"ALGO 1 Beta is: {algo1_beta}")
# Out:
# ALGO 1 Beta is: 0.31491119195199996

# %%
# Plot beta trend
import seaborn as sns
sns.lmplot (x= "S&P TSX" , y= "ALGO1" , data = daily_returns1 , aspect= 1.5 , fit_reg=True )

# %% [markdown]
# ## Rolling Statistics Challenge: Exponentially Weighted Average
#
# An alternative way to calculate a rolling window is to take the exponentially weighted moving average. This is like a moving window average, but it assigns greater importance to more recent observations. Try calculating the [`ewm`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.ewm.html) with a 21-day half-life.

# %%
# Use `ewm` to calculate the rolling window
#Whale Portfolios Returns
#Assume Equal Number of Shares in each Portfolios
weights_whale= [.25, .25 , .25 , .25]
#PAULSON & CO.INC.	TIGER GLOBAL MANAGEMENT LLC	BERKSHIRE HATHAWAY INC
Wha_Portfolios_df1 = whale_df1.dot(weights_whale)
#Wha_Portfolios_df1= (sfml_weight * whale_df1["SOROS FUND MANAGEMENT LLC"] + paul_weight * whale_df1["PAULSON & CO.INC"] + tgml_weight * whale_df1["TIGER GLOBAL MANAGEMENT LLC"] + berk_weight *   whale_df1["BERKSHIRE HATHAWAY INC"])
Wha_Portfolios_df1.head()


#joined_df1.ewm(com=10.5).mean()

#joined_df1.rolling(21).mean()
# Out:
# Date
# 2015-03-03   -0.003328
# 2015-04-03    0.001788
# 2015-05-03    0.004293
# 2015-06-03   -0.008265
# 2015-09-03    0.002249
# dtype: float64

# %%
#Whale Portfolios Exponentially weighted average 
Wha_Portfolios_df1_moving_average = Wha_Portfolios_df1.ewm(halflife=21/2,min_periods=0,adjust=True,ignore_na=False).mean()

Wha_Portfolios_df1_moving_average
# Out:
# Date
# 2015-03-03   -0.003328
# 2015-04-03   -0.000686
# 2015-05-03    0.001085
# 2015-06-03   -0.001489
# 2015-09-03   -0.000639
#                 ...
# 2019-04-25    0.000725
# 2019-04-26    0.001319
# 2019-04-29    0.001482
# 2019-04-30    0.001268
# 2019-01-05    0.000820
# Length: 1059, dtype: float64

# %%
#Algo Returns
#Assume Equal Number of Shares in each Portfolios
weights_algo = [0.5, 0.5]
Algo_Portfolios_df1 = algo_df1.dot(weights_algo)
Algo_Portfolios_df1.head()
# Out:
# Date
# 2014-06-05    0.008674
# 2014-06-06    0.005070
# 2014-06-09    0.000328
# 2014-06-10    0.001835
# 2014-06-11    0.000499
# dtype: float64

# %%
#Algo Portfolios Exponentially weighted average 
Algo_Portfolios_df1_moving_average = Algo_Portfolios_df1.ewm(halflife=21/2,min_periods=0,adjust=True,ignore_na=False).mean()

Algo_Portfolios_df1_moving_average
# Out:
# Date
# 2014-06-05    0.008674
# 2014-06-06    0.006813
# 2014-06-09    0.004507
# 2014-06-10    0.003772
# 2014-06-11    0.003028
#                 ...
# 2019-04-25    0.000406
# 2019-04-26    0.000643
# 2019-04-29    0.000859
# 2019-04-30    0.000660
# 2019-05-01    0.000386
# Length: 1235, dtype: float64

# %% [markdown]
# ---

# %%
#S&P TSX 60 returns Exponentially weighted average
tsx_df1_moving_average = tsx_df1.ewm(halflife=21/2,min_periods=0,adjust=True,ignore_na=False).mean()

tsx_df1_moving_average
# Out:
#              S&P TSX
# Date
# 2012-10-02  0.001701
# 2012-10-03 -0.000501
# 2012-10-04  0.002214
# 2012-10-05  0.000970
# 2012-10-09 -0.001911
# ...              ...
# 2019-12-20  0.000713
# 2019-12-23  0.000706
# 2019-12-24  0.000852
# 2019-12-27  0.000754
# 2019-12-30  0.000446
#
# [1817 rows x 1 columns]

# %%
#plot.figure(figsize=(15,10))
#plot.grid(True)
ax = tsx_df1_moving_average .plot(grid=True, figsize= (25,10), title= "Moving_Average", legend= ["S&P TSX", "WHALES", "ALGOs"])

Wha_Portfolios_df1_moving_average.plot(legend="Whales", ylabel="Portfolios performance vs. S&P TSX 60", ax=ax )
Algo_Portfolios_df1_moving_average.plot(use_index="Algos", legend = "Algo", ax=ax)  
#label='S P TSX 60-ewm with a 21-day half-life.', 
#label='Whale-ewm with a 21-day half-life.',
#label='Algo-ewm with a 21-day half-life.', 
#tsx_df1.plot(label='S P TSX 60-ewm with a 21-day half-life.', figsize= (15,10))
# Out:
# <AxesSubplot:title={'center':'Moving_Average'}, xlabel='Date', ylabel='Portfolios performance vs. S&P TSX 60'>

# %% [markdown]
# # Sharpe Ratios
# In reality, investment managers and thier institutional investors look at the ratio of return-to-risk, and not just returns alone. After all, if you could invest in one of two portfolios, and each offered the same 10% return, yet one offered lower risk, you'd take that one, right?
#
# ### Using the daily returns, calculate and visualize the Sharpe ratios using a bar plot

# %%
# Annualized Sharpe Ratios
sharpe_ratios =(joined_df1.mean() * 252) / (joined_df1.std() * np.sqrt(252))
sharpe_ratios
# Out:
# SFML         0.040444
# P&CO        -0.690550
# TGML        -0.001158
# BERK HAWY    0.243828
# ALGO1        1.240124
# ALGO2        0.036006
# S&P TSX     -0.224147
# dtype: float64

# %%
# Visualize the sharpe ratios as a bar plot
sharpe_ratios.plot(kind="bar" , title="Sharpe Ratios")
# Out:
# <AxesSubplot:title={'center':'Sharpe Ratios'}>

# %% [markdown]
# ### Determine whether the algorithmic strategies outperform both the market (S&P TSX 60) and the whales portfolios.
#
# Write your answer here!

# %% [markdown]
# ---Based on the sharpe ratios, it appears that Algorithmic portfolios' overall risk adjusted returns are superior in comparison to S&P TSX60 and the whales portfolios. ALGO 1 outperforms all other portfolios and its risk adjusted return is 1.24.The low performing ALGO2 risk adjusted return is also positive and higher than S&P TSX. Algortithmic portfolios risk adjusted returns average is 0.63  vs. S&P TSX 60 average risk adjusted return is -0.22 vs. whale portfolios average risk adjusted return is -0.10. Algo investment strategies and risk adjusted returns are more attractive to investors in comparison to S&P TSX 60 and the whale portfolios
#
# Algorithmic strategies got the postive risk adjusted returns on the both selected portfolios whereas Whales portfolios managed to get the positive risk adjusted returns only on 2 out of the 4 selected portfolios. Also, the Whales risk risk adjusted negative returns on 2 portfolios are greater than its risk adjusted postive returns on the other 2 portfolios
# Generally, the greater the value of the Sharpe ratio, the more attractive the risk-adjusted return.

# %% [markdown]
# # Create Custom Portfolio
#
# In this section, you will build your own portfolio of stocks, calculate the returns, and compare the results to the Whale Portfolios and the S&P TSX 60.
#
# 1. Choose 3-5 custom stocks with at last 1 year's worth of historic prices and create a DataFrame of the closing prices and dates for each stock.
# 2. Calculate the weighted returns for the portfolio assuming an equal number of shares for each stock.
# 3. Join your portfolio returns to the DataFrame that contains all of the portfolio returns.
# 4. Re-run the performance and risk analysis with your portfolio to see how it compares to the others.
# 5. Include correlation analysis to determine which stocks (if any) are correlated.

# %% [markdown]
# ## Choose 3-5 custom stocks with at last 1 year's worth of historic prices and create a DataFrame of the closing prices and dates for each stock.
#
# For this demo solution, we fetch data from three companies listes in the S&P TSX 60 index.
#
# * `SHOP` - [Shopify Inc](https://en.wikipedia.org/wiki/Shopify)
#
# * `OTEX` - [Open Text Corporation](https://en.wikipedia.org/wiki/OpenText)
#
# * `L` - [Loblaw Companies Limited](https://en.wikipedia.org/wiki/Loblaw_Companies)

# %%
# Reading data from 1st stock
csv_path = Path("DELL_historical.csv")

dell_data = pd.read_csv(csv_path,index_col='Date',infer_datetime_format=True, parse_dates=True)

dell_data.sort_index()
# Out:
#                      Close
# Date
# 2018-12-21 16:00:00  42.17
# 2018-12-26 16:00:00  44.91
# 2018-12-27 16:00:00  44.60
# 2018-12-28 16:00:00  45.43
# 2018-12-31 16:00:00  48.87
# ...                    ...
# 2019-12-23 16:00:00  50.46
# 2019-12-24 13:00:00  50.83
# 2019-12-26 16:00:00  52.01
# 2019-12-27 16:00:00  50.98
# 2019-12-30 16:00:00  50.91
#
# [256 rows x 1 columns]

# %%
# Reading data from 2nd stock
csv_path = Path("IBM_historical.csv")

ibm_data = pd.read_csv(csv_path,index_col='Date',infer_datetime_format=True, parse_dates=True)
ibm_data.sort_index()
# Out:
#                       Close
# Date
# 2017-01-03 16:00:00  167.19
# 2017-01-04 16:00:00  169.26
# 2017-01-05 16:00:00  168.70
# 2017-01-06 16:00:00  169.53
# 2017-01-09 16:00:00  167.65
# ...                     ...
# 2019-12-23 16:00:00  135.55
# 2019-12-24 13:00:00  134.98
# 2019-12-26 16:00:00  134.91
# 2019-12-27 16:00:00  135.27
# 2019-12-30 16:00:00  132.81
#
# [753 rows x 1 columns]

# %%
# Reading data from 3rd stock
csv_path = Path("pfe_historical.csv")
pfe_data = pd.read_csv(csv_path,index_col='Date',infer_datetime_format=True, parse_dates=True)
pfe_data.sort_index()
# Out:
#                      Close
# Date
# 2017-01-03 16:00:00  31.26
# 2017-01-04 16:00:00  31.54
# 2017-01-05 16:00:00  31.84
# 2017-01-06 16:00:00  31.72
# 2017-01-09 16:00:00  31.71
# ...                    ...
# 2019-12-23 16:00:00  37.25
# 2019-12-24 13:00:00  37.22
# 2019-12-26 16:00:00  37.31
# 2019-12-27 16:00:00  37.25
# 2019-12-30 16:00:00  36.86
#
# [753 rows x 1 columns]

# %%
# Combine all stocks in a single DataFrame

combined_df = pd.concat([ dell_data , ibm_data , pfe_data],axis = "columns" , join ='inner' )

#Sort datetime index in ascending order
combined_df = combined_df.sort_index()

# Set the column names to 'DELL', 'IBM' and 'PFIZER'
combined_df.columns = ["DELL" , "IBM" , "PFIZER" ]


combined_df.head()
# Out:
#                       DELL     IBM  PFIZER
# Date
# 2018-12-21 16:00:00  42.17  110.94   39.72
# 2018-12-26 16:00:00  44.91  111.39   39.97
# 2018-12-27 16:00:00  44.60  113.78   40.59
# 2018-12-28 16:00:00  45.43  113.03   40.70
# 2018-12-31 16:00:00  48.87  113.67   41.35

# %%
# Reset Date index

combined_df.reset_index(inplace = True)
combined_df.head()
# Out:
#                  Date   DELL     IBM  PFIZER
# 0 2018-12-21 16:00:00  42.17  110.94   39.72
# 1 2018-12-26 16:00:00  44.91  111.39   39.97
# 2 2018-12-27 16:00:00  44.60  113.78   40.59
# 3 2018-12-28 16:00:00  45.43  113.03   40.70
# 4 2018-12-31 16:00:00  48.87  113.67   41.35

# %%
# Changing object type column to datetime

combined_df['Date'] = pd.to_datetime(combined_df.Date)

# Creating new column with just the date
combined_df['date'] = combined_df['Date'].dt.date
#Rename a column name
combined_df.rename(columns = {'PFIZER': 'PFE'}, inplace = True) 

#combined_df.drop(['Date'], axis=1)
combined_df.head()                                  


# Reorganize portfolio data by having a column per symbol

# Set the column names to 'AMZN' and 'S&P 500'
#joined_df1.columns = ["SFML" , "P&CO" , "TGML" , "BERK HAWY" , "ALGO1" , "ALGO2" , "S&P TSX"]
# Out:
#                  Date   DELL     IBM    PFE        date
# 0 2018-12-21 16:00:00  42.17  110.94  39.72  2018-12-21
# 1 2018-12-26 16:00:00  44.91  111.39  39.97  2018-12-26
# 2 2018-12-27 16:00:00  44.60  113.78  40.59  2018-12-27
# 3 2018-12-28 16:00:00  45.43  113.03  40.70  2018-12-28
# 4 2018-12-31 16:00:00  48.87  113.67  41.35  2018-12-31

# %%
combined_df.drop(['Date'], axis=1)
# Out:
#       DELL     IBM    PFE        date
# 0    42.17  110.94  39.72  2018-12-21
# 1    44.91  111.39  39.97  2018-12-26
# 2    44.60  113.78  40.59  2018-12-27
# 3    45.43  113.03  40.70  2018-12-28
# 4    48.87  113.67  41.35  2018-12-31
# ..     ...     ...    ...         ...
# 251  50.46  135.55  37.25  2019-12-23
# 252  50.83  134.98  37.22  2019-12-24
# 253  52.01  134.91  37.31  2019-12-26
# 254  50.98  135.27  37.25  2019-12-27
# 255  50.91  132.81  36.86  2019-12-30
#
# [256 rows x 4 columns]

# %%
#Reorder Column

combined_df = combined_df[["date" , "DELL" , "IBM" , "PFE"]]
combined_df.head()
# Out:
#          date   DELL     IBM    PFE
# 0  2018-12-21  42.17  110.94  39.72
# 1  2018-12-26  44.91  111.39  39.97
# 2  2018-12-27  44.60  113.78  40.59
# 3  2018-12-28  45.43  113.03  40.70
# 4  2018-12-31  48.87  113.67  41.35

# %%
# Reorganize portfolio data by having a column per symbol


#df_grp_pfe = combined_df.groupby(['DELL']).mean()

#combined_df_dell= combined_df.reindex(index = ['DELL'] , columns = ['date','DELL' , 'IBM', 'PFE' ])



#combined_df_dell

# %%
df_grp_ibm = combined_df.groupby(['IBM']).mean()

df_grp_ibm
# Out:
#          DELL    PFE
# IBM
# 110.94  42.17  39.72
# 111.39  44.91  39.97
# 112.91  45.13  39.83
# 113.03  45.43  40.70
# 113.67  48.87  41.35
# ...       ...    ...
# 150.32  57.69  36.24
# 150.38  55.46  40.82
# 150.39  55.07  40.42
# 150.88  55.97  39.27
# 151.36  55.28  40.82
#
# [234 rows x 2 columns]

# %%
#Reset Index by Date
combined_df.set_index(['date'], inplace=True)

combined_df.sort_index()


combined_df
# Out:
#              DELL     IBM    PFE
# date
# 2018-12-21  42.17  110.94  39.72
# 2018-12-26  44.91  111.39  39.97
# 2018-12-27  44.60  113.78  40.59
# 2018-12-28  45.43  113.03  40.70
# 2018-12-31  48.87  113.67  41.35
# ...           ...     ...    ...
# 2019-12-23  50.46  135.55  37.25
# 2019-12-24  50.83  134.98  37.22
# 2019-12-26  52.01  134.91  37.31
# 2019-12-27  50.98  135.27  37.25
# 2019-12-30  50.91  132.81  36.86
#
# [256 rows x 3 columns]

# %%
# Calculate daily returns


daily_returns_combined = combined_df.pct_change()

#daily_returns_combined.head()



# Drop NAs

daily_returns_combined1 = daily_returns_combined.dropna()


# Display sample data

daily_returns_combined1.sort_index()
# Out:
#                 DELL       IBM       PFE
# date
# 2018-12-26  0.064975  0.004056  0.006294
# 2018-12-27 -0.006903  0.021456  0.015512
# 2018-12-28  0.018610 -0.006592  0.002710
# 2018-12-31  0.075721  0.005662  0.015971
# 2019-01-02 -0.035809  0.013548 -0.009190
# ...              ...       ...       ...
# 2019-12-23  0.016929 -0.000295  0.002422
# 2019-12-24  0.007333 -0.004205 -0.000805
# 2019-12-26  0.023215 -0.000519  0.002418
# 2019-12-27 -0.019804  0.002668 -0.001608
# 2019-12-30 -0.001373 -0.018186 -0.010470
#
# [255 rows x 3 columns]

# %% [markdown]
# ## Calculate the weighted returns for the portfolio assuming an equal number of shares for each stock

# %%
# Set weights
weights_combined_df = [1/3, 1/3, 1/3]

# Calculate portfolio return


my_portfolio_returns = daily_returns_combined1.dot(weights_combined_df)


# Display sample data

my_portfolio_returns.sort_index()

# %% [markdown]
# ## Join your portfolio returns to the DataFrame that contains all of the portfolio returns

# %%
# Join your returns DataFrame to the original returns DataFrame

#daily_returns_combined1 refers to Dell, IBM & PFE
#joined_df3 refers to whale,Algo & SP TSX 60 

all_joined_df = pd.concat([ joined_df3 , daily_returns_combined1],axis = "columns" , join ='outer' )

#Sort datetime index in ascending order
all_joined_df = all_joined_df .sort_index()
all_joined_df .sort_index()
# Out:
#                 SFML      P&CO      TGML  BERK HAWY     ALGO1     ALGO2  \
# 2015-01-05  0.006051  0.002551  0.006526   0.009650  0.013712 -0.015621
# 2015-01-06  0.002081 -0.000113  0.000837   0.002916  0.002307 -0.011984
# 2015-01-07 -0.001365  0.002100  0.005815  -0.001304  0.003473  0.009418
# 2015-01-09 -0.018980 -0.012439 -0.022997  -0.037577 -0.009436 -0.001881
# 2015-01-12  0.004271  0.010081  0.009055   0.010649 -0.019423 -0.002282
# ...              ...       ...       ...        ...       ...       ...
# 2019-12-23       NaN       NaN       NaN        NaN       NaN       NaN
# 2019-12-24       NaN       NaN       NaN        NaN       NaN       NaN
# 2019-12-26       NaN       NaN       NaN        NaN       NaN       NaN
# 2019-12-27       NaN       NaN       NaN        NaN       NaN       NaN
# 2019-12-30       NaN       NaN       NaN        NaN       NaN       NaN
#
#              S&P TSX      DELL       IBM       PFE
# 2015-01-05 -0.024465       NaN       NaN       NaN
# ...

# %%
# Only compare dates where return data exists for all the stocks (drop NaNs)

all_joined_df1 = all_joined_df.dropna() 
all_joined_df1 .sort_index()
# Out:
#                 SFML      P&CO      TGML  BERK HAWY     ALGO1     ALGO2  \
# 2018-12-27  0.004184 -0.007472  0.009149   0.004813  0.001571  0.000494
# 2018-12-28  0.001145  0.000863 -0.004019  -0.006178  0.014664  0.011664
# 2018-12-31  0.007059  0.005695 -0.004084   0.005696  0.006768  0.005743
# 2019-01-02  0.010911  0.006006 -0.002556   0.001810  0.050342  0.018022
# 2019-01-03  0.005292  0.006227 -0.011270   0.006593  0.015246 -0.011792
# ...              ...       ...       ...        ...       ...       ...
# 2019-04-24  0.002284  0.001009 -0.004000  -0.006386  0.001095  0.000399
# 2019-04-25 -0.000285 -0.001291 -0.005153   0.004848  0.000682 -0.007247
# 2019-04-26  0.008149  0.009162  0.012355   0.010434  0.002981  0.005256
# 2019-04-29  0.001254  0.002719  0.006251   0.005223  0.005208  0.002829
# 2019-04-30 -0.001295 -0.002211 -0.000259  -0.003702 -0.002944 -0.001570
#
#              S&P TSX      DELL       IBM       PFE
# 2018-12-27  0.027940 -0.006903  0.021456  0.015512
# ...

# %% [markdown]
# ## Re-run the risk analysis with your portfolio to see how it compares to the others

# %% [markdown]
# ### Calculate the Annualized Standard Deviation

# %%
# Calculate the annualized `std`
all_joined_df1_daily_std = all_joined_df1.std()
all_joined_df1_daily_std.head(12)
# Out:
# SFML         0.007429
# P&CO         0.007328
# TGML         0.020050
# BERK HAWY    0.012954
# ALGO1        0.008507
# ALGO2        0.007521
# S&P TSX      0.005557
# DELL         0.021460
# IBM          0.015097
# PFE          0.013403
# dtype: float64

# %%
# Calculate Annualized_std = daily_std1 * np.sqrt(252)
all_joined_df1_annualized_std = all_joined_df1_daily_std * np.sqrt(252)
all_joined_df1_annualized_std.head(12)
# Out:
# SFML         0.117932
# P&CO         0.116321
# TGML         0.318277
# BERK HAWY    0.205642
# ALGO1        0.135051
# ALGO2        0.119389
# S&P TSX      0.088220
# DELL         0.340662
# IBM          0.239658
# PFE          0.212765
# dtype: float64

# %% [markdown]
# ### Calculate and plot rolling `std` with 21-day window

# %%
# Calculate rolling standard deviation

all_joined_df1.rolling(window=21).std()
# Out:
#                 SFML      P&CO      TGML  BERK HAWY     ALGO1     ALGO2  \
# 2018-12-27       NaN       NaN       NaN        NaN       NaN       NaN
# 2018-12-28       NaN       NaN       NaN        NaN       NaN       NaN
# 2018-12-31       NaN       NaN       NaN        NaN       NaN       NaN
# 2019-01-02       NaN       NaN       NaN        NaN       NaN       NaN
# 2019-01-03       NaN       NaN       NaN        NaN       NaN       NaN
# ...              ...       ...       ...        ...       ...       ...
# 2019-04-24  0.008919  0.008181  0.010180   0.016439  0.005518  0.006908
# 2019-04-25  0.008853  0.008188  0.010307   0.016436  0.005474  0.006490
# 2019-04-26  0.008970  0.008407  0.010511   0.016413  0.005476  0.006596
# 2019-04-29  0.008849  0.008333  0.010263   0.016374  0.005092  0.006620
# 2019-04-30  0.008347  0.008315  0.009661   0.016352  0.005167  0.006548
#
#              S&P TSX      DELL       IBM       PFE
# 2018-12-27       NaN       NaN       NaN       NaN
# ...

# %%
# Plot rolling standard deviation

all_joined_df1.rolling(window=21).std().plot(fontsize=20, figsize=(15,10))
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Calculate and plot the correlation

# %%
# Calculate  the correlation

correlation_all_joined_df1 = all_joined_df1.corr()
correlation_all_joined_df1
# Out:
#                SFML      P&CO      TGML  BERK HAWY     ALGO1     ALGO2  \
# SFML       1.000000  0.752766  0.339535   0.751098  0.197044  0.580306
# P&CO       0.752766  1.000000  0.240532   0.619541  0.163088  0.471528
# TGML       0.339535  0.240532  1.000000   0.095664 -0.046132  0.060862
# BERK HAWY  0.751098  0.619541  0.095664   1.000000  0.106547  0.420933
# ALGO1      0.197044  0.163088 -0.046132   0.106547  1.000000  0.312207
# ALGO2      0.580306  0.471528  0.060862   0.420933  0.312207  1.000000
# S&P TSX    0.411989  0.151307  0.194210   0.328519  0.073998  0.538263
# DELL       0.212116  0.226667  0.012107   0.160215 -0.125924  0.294216
# IBM        0.264278  0.217223  0.057078   0.245563  0.255402  0.428659
# PFE        0.253644  0.249044 -0.004308   0.239659  0.135634  0.330112
#
#             S&P TSX      DELL       IBM       PFE
# SFML       0.411989  0.212116  0.264278  0.253644
# P&CO       0.151307  0.226667  0.217223  0.249044
# ...

# %%
#plot the correlation

sns.heatmap(correlation_all_joined_df1, vmin=-1, vmax=1 )
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Calculate and Plot the 60-day Rolling Beta for Your Portfolio compared to the S&P 60 TSX

# %%
# Calculate and plot Beta

variance_SP60 =all_joined_df1 ['S&P TSX'].var()

variance_SP60
# Out:
# 3.088394441874698e-05

# %%
covariance_joined_df1 = all_joined_df1.rolling(window=60).cov()


#covariance_dell =all_joined_df1['DELL'].rolling(window=60).cov(all_joined_df1['S&P TSX']
covariance_joined_df1
#covariance = daily_returns1.cov()
                                     
#covariance                                                               
                                                               
#covariance_algo1 =daily_returns1['ALGO1'].cov(daily_returns1['S&P TSX'])
# Out:
#                           SFML      P&CO      TGML  BERK HAWY     ALGO1  \
# 2018-12-27 SFML            NaN       NaN       NaN        NaN       NaN
#            P&CO            NaN       NaN       NaN        NaN       NaN
#            TGML            NaN       NaN       NaN        NaN       NaN
#            BERK HAWY       NaN       NaN       NaN        NaN       NaN
#            ALGO1           NaN       NaN       NaN        NaN       NaN
# ...                        ...       ...       ...        ...       ...
# 2019-04-30 ALGO2      0.000034  0.000027  0.000010   0.000044  0.000019
#            S&P TSX    0.000017  0.000010  0.000018   0.000024  0.000003
#            DELL       0.000036  0.000035  0.000008   0.000048 -0.000027
#            IBM        0.000030  0.000028  0.000014   0.000048  0.000036
#            PFE        0.000026  0.000028 -0.000004   0.000043  0.000016
#
#                          ALGO2   S&P TSX      DELL       IBM       PFE
# ...

# %%
#covariance_dell calculation  
covariance_dell =covariance_joined_df1['DELL'].cov(covariance_joined_df1['S&P TSX']) 
covariance_dell
#Beta Dell Calculation vs. SP TSX 60
beta_dell = covariance_dell / variance_SP60
beta_dell
print(f"Dell Beta is: {beta_dell} is greater than 1 , hence it indicates that it is more volatile and more riskier in comparison to S&P TSX. Overall, its invetments would  retun $1.99 to every $1dollar retun in S&P TSX 60 and similarly would loose $1.99 for every $1 dollar lost in S&P TSX 60")
# Out:
# Dell Beta is: 1.9985573995171115e-05 is greater than 1 , hence it indicates that it is more volatile and more riskier in comparison to S&P TSX. Overall, its invetments would  retun $1.99 to every $1dollar retun in S&P TSX 60 and similarly would loose $1.99 for every $1 dollar lost in S&P TSX 60

# %%
#covariance_ibm calculation  
covariance_ibm =covariance_joined_df1['IBM'].cov(covariance_joined_df1['S&P TSX']) 
covariance_ibm
#Beta Dell Calculation vs. SP TSX 60
beta_ibm = covariance_ibm / variance_SP60
beta_ibm
print(f"IBM Beta is: {beta_ibm} is greater than 1 , hence it indicates that it is more volatile and more riskier in comparison to S&P TSX. Overall, its invetments would  retun $5.95 to every $1dollar retun in S&P TSX 60 and similarly would loose $5.95 for every $1 dollar lost in S&P TSX 60")
# Out:
# IBM Beta is: 5.951126048366833e-06 is greater than 1 , hence it indicates that it is more volatile and more riskier in comparison to S&P TSX. Overall, its invetments would  retun $5.95 to every $1dollar retun in S&P TSX 60 and similarly would loose $5.95 for every $1 dollar lost in S&P TSX 60

# %%
#covariance_pfe calculation  
covariance_pfe =covariance_joined_df1['PFE'].cov(covariance_joined_df1['S&P TSX']) 
covariance_pfe
#Beta Dell Calculation vs. SP TSX 60
beta_pfe = covariance_pfe / variance_SP60
beta_pfe
print(f"Pfizer Beta is: {beta_pfe} is greater than 1 , hence it indicates that it is more volatile and more riskier in comparison to S&P TSX. Overall, its invetments would  retun $5.63 to every $1dollar retun in S&P TSX 60 and similarly would loose $5.63 for every $1 dollar lost in S&P TSX 60")
# Out:
# Pfizer Beta is: 5.635367545935319e-06 is greater than 1 , hence it indicates that it is more volatile and more riskier in comparison to S&P TSX. Overall, its invetments would  retun $5.63 to every $1dollar retun in S&P TSX 60 and similarly would loose $5.63 for every $1 dollar lost in S&P TSX 60

# %%
# Plot Dell beta trend
import seaborn as sns

sns.lmplot (x= "S&P TSX" , y= "DELL" , data = covariance_joined_df1 , aspect= 3.0 , fit_reg=True)

# %%
# Plot IBM beta trend
import seaborn as sns
sns.lmplot (x= "S&P TSX" , y= "IBM" , data = covariance_joined_df1 , aspect= 3.0 , fit_reg=True )

# %%
# Plot Dell beta trend
import seaborn as sns
sns.lmplot (x= "S&P TSX" , y= "PFE" , data = covariance_joined_df1 , aspect= 3.0 , fit_reg=True )

# %% [markdown]
# ### Using the daily returns, calculate and visualize the Sharpe ratios using a bar plot

# %%
# Calculate Annualzied Sharpe Ratios

sharpe_ratios_all =(all_joined_df1.mean() * 252) / (all_joined_df1.std() * np.sqrt(252))
sharpe_ratios_all.head(11)
# Out:
# SFML         5.055354
# P&CO         2.552936
# TGML        -0.316912
# BERK HAWY    4.410762
# ALGO1        4.094379
# ALGO2        5.669554
# S&P TSX      5.939074
# DELL         4.327234
# IBM          3.166391
# PFE          0.761189
# dtype: float64

# %%
# Visualize the sharpe ratios as a bar plot
sharpe_ratios_all.plot(kind="bar" , title="Sharpe Ratios")
# Out:
# <AxesSubplot:title={'center':'Sharpe Ratios'}>

# %% [markdown]
# ### How does your portfolio do?
#
# Write your answer here!

# %%
"--- My risk adjusted returns appear to be better than the whale portfolios for the selected time period. But SP TSX risk adjusted returns during that time outperformed all other stock  in my portfolio. Overall ALGOs returns and strategy appears to be superior than my portfolio during the given period  "
# Out:
# '--- My risk adjusted returns appear to be better than the whale portfolios for the selected time period. But SP TSX risk adjusted returns during that time outperformed all other stock  in my portfolio. Overall ALGOs returns and strategy appears to be superior than my portfolio during the given period  '
